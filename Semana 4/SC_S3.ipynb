# %% [markdown]
# # INEGI:

# %%
import requests
import pandas as pd

url = "https://www.inegi.org.mx/app/tabulados/serviciocuadros/wsDataService.svc/listaindicadorbiinegi/910492/false/0700/es/json/2000/2026//0//0/3"
response = requests.get(url)

# %%
response.json()
# Out:
# [{'Data': [{'MetaData': {'Abbreviation': 'EUM',
#      'Description': None,
#      'Entity': 'Estados Unidos Mexicanos',
#      'Excepcion': None,
#      'Freq': 'Mensual',
#      'Indicador': '910492',
#      'LastUpdate': '09/04/2026 12:00:00 a. m.',
#      'Name': 'INPP con Petróleo y con Servicios',
#      'NoOfDecimals': '3',
#      'Note': '',
#      'Preliminary': None,
#      'ShortName': '',
#      'Source': 'INEGI. Índice Nacional de Precios Productor (INPP).',
#      'SourceUrl': '/programas/inpp/2019a/',
#      'Title': None,
#      'Town': '',
#      'Unit': 'Índice base julio 2019 = 100',
#      'factor': '',
#      'reltabse': [{'tbds': 'esib', 'tbema': 'osap_eib', 'tbnc': 'as_oa'}],
#      'ultimoper': '2026 Mar'},
#     'Serie': {'Obs': [{'CurrentValue': '48.719766378275',
#        'TimePeriod': '2003/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '49.037419255061',
#        'TimePeriod': '2004/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '49.622543649264',
#        'TimePeriod': '2004/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '50.193052113554',
#        'TimePeriod': '2004/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '50.699737683888',
#        'TimePeriod': '2004/04',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '51.026160118622',
#        'TimePeriod': '2004/05',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '51.340402611762',
#        'TimePeriod': '2004/06',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '51.641977965644',
#        'TimePeriod': '2004/07',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '51.965477214395',
#        'TimePeriod': '2004/08',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '52.139406780366',
#        'TimePeriod': '2004/09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '52.431725378635',
#        'TimePeriod': '2004/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '52.678247396510',
#        'TimePeriod': '2004/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '52.687504152121',
#        'TimePeriod': '2004/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '52.921846228401',
#        'TimePeriod': '2005/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '53.147905944396',
#        'TimePeriod': '2005/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '53.436814159019',
#        'TimePeriod': '2005/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '53.581024667499',
#        'TimePeriod': '2005/04',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '53.595153399749',
#        'TimePeriod': '2005/05',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '53.658976293704',
#        'TimePeriod': '2005/06',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '54.042888052765',
#        'TimePeriod': '2005/07',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '54.109634132703',
#        'TimePeriod': '2005/08',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '54.247023873890',
#        'TimePeriod': '2005/09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '54.443364532394',
#        'TimePeriod': '2005/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '54.562240762357',
#        'TimePeriod': '2005/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '54.795121245646',
#        'TimePeriod': '2005/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '55.273549351480',
#        'TimePeriod': '2006/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '55.445042929132',
#        'TimePeriod': '2006/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '55.745156690022',
#        'TimePeriod': '2006/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '56.353179374423',
#        'TimePeriod': '2006/04',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '56.987023535004',
#        'TimePeriod': '2006/05',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '57.349985794522',
#        'TimePeriod': '2006/06',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '57.688100973188',
#        'TimePeriod': '2006/07',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '57.918545468157',
#        'TimePeriod': '2006/08',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '57.927802223769',
#        'TimePeriod': '2006/09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '57.768488587712',
#        'TimePeriod': '2006/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '57.913673491519',
#        'TimePeriod': '2006/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '58.149477160790',
#        'TimePeriod': '2006/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '58.188452973892',
#        'TimePeriod': '2007/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '58.553364024066',
#        'TimePeriod': '2007/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue':
09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.465625642252',
#        'TimePeriod': '2022/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.175600970250',
#        'TimePeriod': '2022/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.181166589310',
#        'TimePeriod': '2022/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.682970381226',
#        'TimePeriod': '2023/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.635992066867',
#        'TimePeriod': '2023/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.885751204592',
#        'TimePeriod': '2023/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.973861916805',
#        'TimePeriod': '2023/04',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.559238014016',
#        'TimePeriod': '2023/05',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.212886014090',
#        'TimePeriod': '2023/06',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '120.601433707173',
#        'TimePeriod': '2023/07',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '121.130501905314',
#        'TimePeriod': '2023/08',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '121.504194405814',
#        'TimePeriod': '2023/09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '122.046844790942',
#        'TimePeriod': '2023/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '121.694009870014',
#        'TimePeriod': '2023/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '121.364309726357',
#        'TimePeriod': '2023/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '121.912233546723',
#        'TimePeriod': '2024/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '122.410458245388',
#        'TimePeriod': '2024/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '123.298272275213',
#        'TimePeriod': '2024/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '123.992607861718',
#        'TimePeriod': '2024/04',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '124.581559665018',
#        'TimePeriod': '2024/05',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '126.261876460330',
#        'TimePeriod': '2024/06',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '127.016118012010',
#        'TimePeriod': '2024/07',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '127.104511541357',
#        'TimePeriod': '2024/08',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '127.736833866600',
#        'TimePeriod': '2024/09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '128.203926866036',
#        'TimePeriod': '2024/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '129.413847659242',
#        'TimePeriod': '2024/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '130.405784353402',
#        'TimePeriod': '2024/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '131.336706161274',
#        'TimePeriod': '2025/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '132.084394183358',
#        'TimePeriod': '2025/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '132.194259645702',
#        'TimePeriod': '2025/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '132.511890555868',
#        'TimePeriod': '2025/04',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '132.529420537779',
#        'TimePeriod': '2025/05',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '132.442302737802',
#        'TimePeriod': '2025/06',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '131.807552912388',
#        'TimePeriod': '2025/07',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '131.343289778290',
#        'TimePeriod': '2025/08',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '131.641194000000',
#        'TimePeriod': '2025/09',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '131.980531939775',
#        'TimePeriod': '2025/10',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '132.481923595456',
#        'TimePeriod': '2025/11',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '133.128372825809',
#        'TimePeriod': '2025/12',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '133.294768467889',
#        'TimePeriod': '2026/01',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '133.547711990105',
#        'TimePeriod': '2026/02',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'},
#       {'CurrentValue': '135.850293428648',
#        'TimePeriod': '2026/03',
#        'ValueNoNumeric': '',
#        'ValueStatus': 'Definitiva'}]}}]}]

# %%
response.json()[0]['Data'][0]['Serie']['Obs'][1]['CurrentValue']
# Out:
# '49.037419255061'

# %%
data = response.json()[0]['Data']
metadata = data[0]['MetaData']
obs = data[0]['Serie']['Obs']
df = pd.DataFrame(obs)
df['Unit'] = metadata['Unit']
df['Indicador'] = metadata['Indicador']
df['Name'] = metadata['Name']
df['Freq'] = metadata['Freq']

df
# Out:
#          CurrentValue TimePeriod ValueNoNumeric ValueStatus  \
# 0     48.719766378275    2003/12                 Definitiva
# 1     49.037419255061    2004/01                 Definitiva
# 2     49.622543649264    2004/02                 Definitiva
# 3     50.193052113554    2004/03                 Definitiva
# 4     50.699737683888    2004/04                 Definitiva
# ..                ...        ...            ...         ...
# 263  132.481923595456    2025/11                 Definitiva
# 264  133.128372825809    2025/12                 Definitiva
# 265  133.294768467889    2026/01                 Definitiva
# 266  133.547711990105    2026/02                 Definitiva
# 267  135.850293428648    2026/03                 Definitiva
#
#                              Unit Indicador  \
# 0    Índice base julio 2019 = 100    910492
# 1    Índice base julio 2019 = 100    910492
# 2    Índice base julio 2019 = 100    910492
# 3    Índice base julio 2019 = 100    910492
# 4    Índice base julio 2019 = 100    910492
# ..                            ...       ...
# 263  Índice base julio 2019 = 100    910492
# 264  Índice base julio 2019 = 100    910492
# 265  Índice base julio 2019 = 100    910492
# 266  Índice base julio 2019 = 100    910492
# 267  Índice base julio 2019 = 100    910492
#
#                                   Name     Freq
# 0    INPP con Petróleo y con Servicios  Mensual
# 1    INPP con Petróleo y con Servicios  Mensual
# 2    INPP con Petróleo y con Servicios  Mensual
# 3    INPP con Petróleo y con Servicios  Mensual
# 4    INPP con Petróleo y con Servicios  Mensual
# ..                                 ...      ...
# 263  INPP con Petróleo y con Servicios  Mensual
# 264  INPP con Petróleo y con Servicios  Mensual
# 265  INPP con Petróleo y con Servicios  Mensual
# 266  INPP con Petróleo y con Servicios  Mensual
# 267  INPP con Petróleo y con Servicios  Mensual
#
# [268 rows x 8 columns]

# %%
df['CurrentValue'].astype(float).plot()
# Out:
# <Axes: >

# %% [markdown]
# # Serie A:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def get_table(url):
    response = requests.get(url)

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    tables = soup.find_all('table', {'cellpadding': '3', 'cellspacing': '1', 'class': 'standard_tabelle'})
    table = tables[0]

    rows = table.find_all('tr')
    # Iterate over each row
    df_all = pd.DataFrame()
    for row in rows:
        df = pd.DataFrame({'date': [row.find_all('td')[0].text.strip()],
                           'time': [row.find_all('td')[1].text.strip()],
                           'team1': [row.find_all('td')[2].text.strip()],
                           'team2': [row.find_all('td')[4].text.strip()],
                           'score': [row.find_all('td')[5].text.strip()]})
        df_all = pd.concat([df_all, df])
        
    return df_all

df_all = pd.DataFrame()

n=38
for i in range(1, n+1):
    print(f"Scraping page {i} out of {n}.")
    url = f"https://www.worldfootball.net/schedule/ita-serie-a-2023-2024-spieltag/{i}/"
    df_all = pd.concat([df_all, get_table(url)])


df_all
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup
#       3 import pandas as pd
#       6 def get_table(url):
#
# ModuleNotFoundError: No module named 'bs4'

# %%
url = f"https://www.worldfootball.net/schedule/ita-serie-a-2023-2024-spieltag/1/"
response = requests.get(url)

response

# %% [markdown]
# # DANE:

# %%
url = f"https://www.dane.gov.co/index.php/estadisticas-por-tema/cuentas-nacionales/cuentas-nacionales-trimestrales/historicos-producto-interno-bruto-pib"
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
soup


tables = soup.find_all('table', {'summary': 'Periodo de referencia 2023', 'class': 'table-bordered basic-table'})
table = tables[0]
table

rows = table.find_all('tr')
rows

links = soup.find_all('a', {'class': 'descarga'})
for i in range(8):
    print(links[i]['href'])
